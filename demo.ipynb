# %%
import torch
from src.runner import Runner
import os
import json

# %%
#model_configs = "alice.json"
model_configs = "cn_poems.json"

configs_dir = os.path.join("configs", model_configs)
runner = Runner(configs_dir)

# %%
w = 100
char_map = runner.dataset.char_map
print(len(char_map))
for i in range(len(char_map)//w+1):
    print(char_map[i*w: i*w+w])
# Out:
# 5420
# ['\n', '，', '。', '「', '」', '不', '人', '山', '天', '日', '风', '无', '云', '有', '何', '一', '君', '白', '江', '中', '来', '相', '水', '时', '为', '月', '长', '上', '行', '生', '春', '我', '子', '花', '自', '见', '此', '如', '秋', '心', '年', '高', '归', '三', '清', '青', '知', '得', '夜', '马', '下', '去', '在', '明', '东', '万', '落', '未', '空', '南', '道', '金', '门', '今', '十', '客', '西', '别', '里', '与', '流', '城', '飞', '事', '出', '玉', '歌', '朝', '多', '已', '地', '远', '公', '酒', '之', '老', '可', '海', '千', '王', '书', '将', '入', '回', '复', '游', '草', '阳', '安', '前']
# ...

# %%
text_in = " "
length = 500
runner.generate_text(None, text_in, length)
# Out:
# Input:
#
# Generation:
# 	 ，独泛河梁过碧碧。
#
# 「赠饶处士」
# 龚稚比吴楚，奇人不惜人。
# 孔戈犹在地，掖客尚强缝。
# 欲有尊中酒，沉空雨暂无。
# 我怜阴颍少，华海月三圆。
# 有感众鱼会，提携好玉携。
#
# 「寄河洛少在作」
# 玉石遗声秋，天地过圣时。
# 侯心与楚县，凫首望云台。
# 不惬平生钓，还知旧旧长。
# 青尘道幽赏，百里见秋毫。
# 岂是楚萍恨，难知音信违。
#
# 「早秋江祖邑中作」
# 君有秋山下，我为邹鲁乡。
# 九天开北壑，不作楚山明。
# 沧海远西蜀，西登云日高。
# 石禽俯万斛，凤卷临瑶池。
# 因想巢由势，优游天子宾。
# 猛将出燕赵，浴目何不精。
# 锦衾澹千里，绮户入玄玄。
# 事蜀若神仙，空秦是玉女。
# 剑弹南浦雁，何必入吴京。
# 十见不敢言，出沉不足雄。
# 还骑四公子，畏物犹弃臣。
# 愁杀白铜杖，汉阳空已穷。
# 愿倚两挥剑，十三同百人。
# 击颜感不顾，顾者俱精才。
# 脱身与青腾，使物惭岳尝。
# 相对一樽酒，纵度明月晖。
# 憔悴身上来，冥冥信终猿。
# 所贵妾酒字，可怜丹屏英。
# 前宫无珠莫，佳人亦星稀。
# 一词陇西去，左右绮罗台。
# 而今都焉赵，弦丝何足飞。
# 相思俱为越，巢处意自多。
# 芳草歇应思，岩泉犹在兹。
# 良粉亦攀折，容易甘其身。
# 多当愧高论，暂伴月中圆。
#
# 「听鬼部」
